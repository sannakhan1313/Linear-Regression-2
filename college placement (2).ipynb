# %% [markdown]
# # college placement dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('College Placement Data.csv')

# %%
df
# Out:
#      s_id              Name gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# 0     1.0       Rick Hansen      M  67.00   Others  91.00   Others  Commerce
# 1     2.0     Justin Ritter      M  79.33  Central  78.33   Others   Science
# 2     3.0      Craig Reiter      M  65.00  Central  68.00  Central      Arts
# 3     4.0  Katherine Murray      M  56.00  Central  52.00  Central   Science
# 4     5.0       Rick Hansen      M  85.80  Central  73.60  Central  Commerce
# ..    ...               ...    ...    ...      ...    ...      ...       ...
# 365   NaN               NaN    NaN    NaN      NaN    NaN      NaN       NaN
# 366   NaN               NaN    NaN    NaN      NaN    NaN      NaN       NaN
# 367   NaN               NaN    NaN    NaN      NaN    NaN      NaN       NaN
# 368   NaN               NaN    NaN    NaN      NaN    NaN      NaN       NaN
# 369   NaN               NaN    NaN    NaN      NaN    NaN      NaN       NaN
#
# ...

# %%
df.shape
# Out:
# (370, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370 entries, 0 to 369
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   s_id            215 non-null    float64
#  1   Name            215 non-null    object
#  2   gender          215 non-null    object
#  3   ssc_p           215 non-null    float64
#  4   ssc_b           215 non-null    object
#  5   hsc_p           215 non-null    float64
#  6   hsc_b           215 non-null    object
#  7   hsc_s           215 non-null    object
#  8   degree_p        215 non-null    float64
#  9   degree_t        215 non-null    object
#  10  specialisation  215 non-null    object
#  11  mba_p           215 non-null    float64
#  12  workex          215 non-null    object
#  13  etest_p         215 non-null    float64
#  14  status          215 non-null    object
#  15  Salary          215 non-null    float64
# dtypes: float64(7), object(9)
# ...

# %%
df.shape
# Out:
# (370, 16)

# %%
df=df.iloc[:215,:]

# %%
df.isnull().sum()
# Out:
# s_id              0
# Name              0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# specialisation    0
# mba_p             0
# workex            0
# etest_p           0
# status            0
# Salary            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   s_id            215 non-null    float64
#  1   Name            215 non-null    object
#  2   gender          215 non-null    object
#  3   ssc_p           215 non-null    float64
#  4   ssc_b           215 non-null    object
#  5   hsc_p           215 non-null    float64
#  6   hsc_b           215 non-null    object
#  7   hsc_s           215 non-null    object
#  8   degree_p        215 non-null    float64
#  9   degree_t        215 non-null    object
#  10  specialisation  215 non-null    object
#  11  mba_p           215 non-null    float64
#  12  workex          215 non-null    object
#  13  etest_p         215 non-null    float64
#  14  status          215 non-null    object
#  15  Salary          215 non-null    float64
# dtypes: float64(7), object(9)
# ...

# %%
df.describe()
# Out:
#              s_id       ssc_p       hsc_p    degree_p       mba_p     etest_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   62.278186   68.258186
# std     62.209324   10.827205   10.897509    7.358743    5.833385   21.084881
# min      1.000000   40.890000   37.000000   50.000000   51.210000    0.000000
# 25%     54.500000   60.600000   60.900000   61.000000   57.945000   59.500000
# 50%    108.000000   67.000000   65.000000   66.000000   62.000000   70.000000
# 75%    161.500000   75.700000   73.000000   72.000000   66.255000   82.830000
# max    215.000000   89.400000   97.700000   91.000000   77.890000   98.000000
#
#               Salary
# count     215.000000
# mean   198702.325581
# std    154780.926716
# min         0.000000
# 25%         0.000000
# 50%    240000.000000
# 75%    282500.000000
# max    940000.000000

# %%
#genderwise ssc %
df.groupby('gender')['ssc_p'].mean()
# Out:
# gender
# F    68.310921
# M    66.752518
# Name: ssc_p, dtype: float64

# %%
df['ssc_b'].value_counts()
# Out:
# Central    116
# Others      99
# Name: ssc_b, dtype: int64

# %%
#genderwise hsc%
df.groupby('gender')['hsc_p'].mean()
# Out:
# gender
# F    66.646842
# M    66.161655
# Name: hsc_p, dtype: float64

# %%
df['hsc_s'].value_counts()
# Out:
# Commerce    113
# Science      91
# Arts         11
# Name: hsc_s, dtype: int64

# %%
#genderwise degree %
df.groupby('gender')['degree_p'].mean()
# Out:
# gender
# F    68.090000
# M    65.429856
# Name: degree_p, dtype: float64

# %%
df['degree_t'].value_counts()
# Out:
# Comm&Mgmt    145
# Sci&Tech      59
# Others        11
# Name: degree_t, dtype: int64

# %%
df['specialisation'].value_counts()
# Out:
# Mkt&Fin    120
# Mkt&HR      95
# Name: specialisation, dtype: int64

# %%
#genderwise mba %
df.groupby('gender')['mba_p'].mean()
# Out:
# gender
# F    64.643553
# M    60.984892
# Name: mba_p, dtype: float64

# %%
df['workex'].value_counts()
# Out:
# No     141
# Yes     74
# Name: workex, dtype: int64

# %%
#genderwise etest %
df.groupby('gender')['etest_p'].mean()
# Out:
# gender
# F    66.020658
# M    69.481583
# Name: etest_p, dtype: float64

# %%
df['status'].value_counts()
# Out:
# Placed        148
# Not Placed     67
# Name: status, dtype: int64

# %%
#genderwise salary 
df.groupby('gender')['Salary'].mean()
# Out:
# gender
# F    168815.789474
# M    215043.165468
# Name: Salary, dtype: float64

# %%
#person getting highest ssc%
df[df['ssc_p'] == max(df['ssc_p'])]
# Out:
#       s_id            Name gender  ssc_p   ssc_b  hsc_p   hsc_b    hsc_s  \
# 145  146.0  Mike Pelletier      M   89.4  Others  65.66  Others  Science
#
#      degree_p  degree_t specialisation  mba_p workex  etest_p  status  \
# 145     71.25  Sci&Tech         Mkt&HR  63.23     No     72.0  Placed
#
#        Salary
# 145  400000.0

# %%
#person getting lowest ssc%
df[df['ssc_p'] == min(df['ssc_p'])]
# Out:
#     s_id         Name gender  ssc_p   ssc_b  hsc_p   hsc_b     hsc_s  \
# 52  53.0  Harold Ryan      F  40.89  Others  45.83  Others  Commerce
#
#     degree_p   degree_t specialisation  mba_p workex  etest_p      status  \
# 52      53.0  Comm&Mgmt         Mkt&HR  65.49     No     71.2  Not Placed
#
#     Salary
# 52     0.0

# %%
#person getting highest hsc%
df[df['hsc_p'] == max(df['hsc_p'])]
# Out:
#     s_id          Name gender  ssc_p   ssc_b  hsc_p   hsc_b    hsc_s  \
# 24  25.0  Naresj Patel      M   76.5  Others   97.7  Others  Science
#
#     degree_p  degree_t specialisation  mba_p workex  etest_p  status    Salary
# 24     78.86  Sci&Tech        Mkt&Fin  74.01     No     97.4  Placed  360000.0

# %%
#person getting lowest hsc%
df[df['hsc_p'] == min(df['hsc_p'])]
# Out:
#     s_id         Name gender  ssc_p   ssc_b  hsc_p   hsc_b hsc_s  degree_p  \
# 49  50.0  John Huston      F   50.0  Others   37.0  Others  Arts      52.0
#
#    degree_t specialisation  mba_p workex  etest_p      status  Salary
# 49   Others         Mkt&HR  56.11     No     65.0  Not Placed     0.0

# %%
#person getting highest degree %
df[df['degree_p']== max(df['degree_p'])]
# Out:
#       s_id            Name gender  ssc_p   ssc_b  hsc_p   hsc_b    hsc_s  \
# 197  198.0  Yoseph Carroll      F  83.96  Others   53.0  Others  Science
#
#      degree_p  degree_t specialisation  mba_p workex  etest_p  status  \
# 197      91.0  Sci&Tech         Mkt&HR  69.71     No      0.0  Placed
#
#        Salary
# 197  260000.0

# %%
#person getting lowest degree%
index=np.argmin(df['degree_p'])
df.loc[index]
# Out:
# s_id                      15.0
# Name              Peter Fuller
# gender                       M
# ssc_p                     62.0
# ssc_b                  Central
# hsc_p                     47.0
# hsc_b                  Central
# hsc_s                 Commerce
# degree_p                  50.0
# degree_t             Comm&Mgmt
# specialisation          Mkt&HR
# mba_p                    54.96
# workex                      No
# etest_p                   76.0
# status              Not Placed
# Salary                     0.0
# Name: 14, dtype: object

# %%
#person getting lowest degree%
df[df['degree_p']== min(df['degree_p'])]
# Out:
#     s_id          Name gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# 14  15.0  Peter Fuller      M   62.0  Central   47.0  Central  Commerce
#
#     degree_p   degree_t specialisation  mba_p workex  etest_p      status  \
# 14      50.0  Comm&Mgmt         Mkt&HR  54.96     No     76.0  Not Placed
#
#     Salary
# 14     0.0

# %%
#person getting highest mba%
index=np.argmax(df['mba_p'])
df.loc[index]
# Out:
# s_id                         20.0
# Name              Ritsa Hightower
# gender                          M
# ssc_p                        60.0
# ssc_b                      Others
# hsc_p                        67.0
# hsc_b                      Others
# hsc_s                        Arts
# degree_p                     70.0
# degree_t                Comm&Mgmt
# specialisation            Mkt&Fin
# mba_p                       77.89
# workex                        Yes
# etest_p                     50.48
# status                     Placed
# Salary                   236000.0
# Name: 19, dtype: object

# %%
#person getting lowest mba%
index=np.argmin(df['mba_p'])
df.loc[index]
# Out:
# s_id                     43.0
# Name              Vivek Grady
# gender                      M
# ssc_p                    49.0
# ssc_b                  Others
# hsc_p                    39.0
# hsc_b                 Central
# hsc_s                 Science
# degree_p                 65.0
# degree_t               Others
# specialisation        Mkt&Fin
# mba_p                   51.21
# workex                     No
# etest_p                  63.0
# status             Not Placed
# Salary                    0.0
# Name: 42, dtype: object

# %%
#person getting highest etest%
df[df['etest_p']== max(df['etest_p'])]
# Out:
#       s_id         Name gender  ssc_p   ssc_b  hsc_p    hsc_b    hsc_s  \
# 152  153.0  Dave Brooks      F   75.4  Others   60.5  Central  Science
#
#      degree_p  degree_t specialisation  mba_p workex  etest_p  status  \
# 152      84.0  Sci&Tech        Mkt&Fin  65.25     No     98.0  Placed
#
#        Salary
# 152  240000.0

# %%
#person getting lowest etest%
df[df['etest_p']== min(df['etest_p'])]
# Out:
#       s_id               Name gender  ssc_p    ssc_b  hsc_p    hsc_b  \
# 9     10.0        Joseph Holt      M  58.00  Central  70.00  Central
# 21    22.0       Sue Ann Reed      F  79.00   Others  76.00   Others
# 37    38.0     Grant Thornton      F  79.00  Central  76.00  Central
# 41    42.0        Barry Franz      F  74.00   Others  63.16   Others
# 51    52.0       Trudy Glocke      M  54.40  Central  61.12  Central
# 69    70.0      Dianna Wilson      M  73.00  Central  73.00  Central
# 105  106.0  Patrick O'Donnell      M  59.00  Central  64.00   Others
# 107  108.0    Adam Bellavance      M  82.00   Others  90.00   Others
# 158  159.0      Karen Daniels      M  67.00   Others  63.00   Others
# 171  172.0      Cindy Stewart      M  80.00   Others  80.00   Others
# 197  198.0     Yoseph Carroll      F  83.96   Others  53.00   Others
# 213  214.0          Mary Zewe      F  74.00   Others  66.00   Others
#
# ...

# %%
#no of person who are placed or not
df['status'].value_counts()
# Out:
# Placed        148
# Not Placed     67
# Name: status, dtype: int64

# %%
#person getting highest salary
index=np.argmax(df['Salary'])
df.loc[index]
# Out:
# s_id                         120.0
# Name              Vivek Sundaresam
# gender                           M
# ssc_p                         60.8
# ssc_b                      Central
# hsc_p                         68.4
# hsc_b                      Central
# hsc_s                     Commerce
# degree_p                      64.6
# degree_t                 Comm&Mgmt
# specialisation             Mkt&Fin
# mba_p                        64.34
# workex                         Yes
# etest_p                      82.66
# status                      Placed
# Salary                    940000.0
# Name: 119, dtype: object

# %%
#person getting lowest salary
df[df['Salary']== min(df['Salary'])]
# Out:
#       s_id              Name gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# 3      4.0  Katherine Murray      M   56.0  Central   52.0  Central   Science
# 5      6.0       Jim Mitchum      M   55.0   Others   49.8   Others   Science
# 6      7.0     Toby Swindell      F   46.0   Others   49.2   Others  Commerce
# 9     10.0       Joseph Holt      M   58.0  Central   70.0  Central  Commerce
# 12    13.0   Magdelene Morse      F   47.0  Central   55.0   Others   Science
# ..     ...               ...    ...    ...      ...    ...      ...       ...
# 198  199.0     Daniel Raglin      F   67.0  Central   70.0  Central  Commerce
# 201  202.0      Tom Ashbrook      M   54.2  Central   63.0   Others   Science
# 206  207.0     Steven Roelle      M   41.0  Central   42.0  Central   Science
# 208  209.0      Larry Hughes      F   43.0  Central   60.0   Others   Science
# 214  215.0         Kent Will      M   62.0  Central   58.0   Others   Science
#
# ...

# %%
#person getting highest & lowest salary
data=df.groupby('Name')['Salary'].sum().sort_values()
print('minimum salary',data.index[0], data.values[0])
print('maximum salary', data.index[-1], data.values[-1])
# Out:
# minimum salary John Lee 0.0
# maximum salary Phillip Breyer 1190000.0

# %%
#person getting highest & lowest salary who is a male
data2=df[df['gender']=='M'].groupby('Name')['Salary'].sum().sort_values()
print(data2.index[-1], data2.values[-1])
print(data2.index[0], data2.values[0])
# Out:
# Phillip Breyer 1190000.0
# Katharine Harms 0.0

# %%
#person getting highest & lowest salary who is a female
data3=df[df['gender']=='F'].groupby('Name')['Salary'].sum().sort_values()
print(data3.index[-1], data3.values[-1])
print(data3.index[0], data3.values[0])
# Out:
# Maria Zettner 650000.0
# Toby Swindell 0.0

# %%
#departmentwise salary/which dept is getting more salary
df.groupby('specialisation')['Salary'].mean()
# Out:
# specialisation
# Mkt&Fin    236591.666667
# Mkt&HR     150842.105263
# Name: Salary, dtype: float64

# %%
#streamwise hsc%/which stream is getting highest %
df.groupby('hsc_s')['hsc_p'].mean()
# Out:
# hsc_s
# Arts        62.745455
# Commerce    68.999115
# Science     63.456374
# Name: hsc_p, dtype: float64

# %%
#departmentwise degree%
df.groupby('degree_t')['degree_p'].mean()
# Out:
# degree_t
# Comm&Mgmt    66.203103
# Others       60.666364
# Sci&Tech     67.844237
# Name: degree_p, dtype: float64

# %%
#specialisation wise mba%
df.groupby('specialisation')['mba_p'].mean()
# Out:
# specialisation
# Mkt&Fin    62.825667
# Mkt&HR     61.586632
# Name: mba_p, dtype: float64

# %%
df.describe()
# Out:
#              s_id       ssc_p       hsc_p    degree_p       mba_p     etest_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   62.278186   68.258186
# std     62.209324   10.827205   10.897509    7.358743    5.833385   21.084881
# min      1.000000   40.890000   37.000000   50.000000   51.210000    0.000000
# 25%     54.500000   60.600000   60.900000   61.000000   57.945000   59.500000
# 50%    108.000000   67.000000   65.000000   66.000000   62.000000   70.000000
# 75%    161.500000   75.700000   73.000000   72.000000   66.255000   82.830000
# max    215.000000   89.400000   97.700000   91.000000   77.890000   98.000000
#
#               Salary
# count     215.000000
# mean   198702.325581
# std    154780.926716
# min         0.000000
# 25%         0.000000
# 50%    240000.000000
# 75%    282500.000000
# max    940000.000000

# %%
df.corr()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3780\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#               s_id     ssc_p     hsc_p  degree_p     mba_p   etest_p    Salary
# s_id      1.000000 -0.078155 -0.085711 -0.088281  0.022327  0.070013  0.002543
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.388478  0.083485  0.538090
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.354823  0.090432  0.452569
# degree_p -0.088281  0.538404  0.434206  1.000000  0.402364  0.070557  0.408371
# mba_p     0.022327  0.388478  0.354823  0.402364  1.000000  0.082318  0.139823
# etest_p   0.070013  0.083485  0.090432  0.070557  0.082318  1.000000  0.153629
# Salary    0.002543  0.538090  0.452569  0.408371  0.139823  0.153629  1.000000

# %%
plt.scatter(df['ssc_p'],df['Salary'])

# %%
df
# Out:
#       s_id              Name gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# 0      1.0       Rick Hansen      M  67.00   Others  91.00   Others  Commerce
# 1      2.0     Justin Ritter      M  79.33  Central  78.33   Others   Science
# 2      3.0      Craig Reiter      M  65.00  Central  68.00  Central      Arts
# 3      4.0  Katherine Murray      M  56.00  Central  52.00  Central   Science
# 4      5.0       Rick Hansen      M  85.80  Central  73.60  Central  Commerce
# ..     ...               ...    ...    ...      ...    ...      ...       ...
# 210  211.0         Ken Black      M  80.60   Others  82.00   Others  Commerce
# 211  212.0  Logan Haushalter      M  58.00   Others  60.00   Others   Science
# 212  213.0     Eleni McCrary      M  67.00   Others  67.00   Others  Commerce
# 213  214.0         Mary Zewe      F  74.00   Others  66.00   Others  Commerce
# 214  215.0         Kent Will      M  62.00  Central  58.00   Others   Science
#
# ...

# %%
df.drop(['s_id','Name'],axis=1,inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3780\610459318.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['s_id','Name'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (215, 14)

# %%
#from sklearn.preprocessing import LabelEncoder, OneHotEncoder
#lb=LabelEncoder()
#X[:,0]= lb.fit_transform(X[:,0])
#X[:,2]= lb.fit_transform(X[:,2])
#X[:,4]= lb.fit_transform(X[:,4])
#X[:,8]= lb.fit_transform(X[:,8])
#X[:,10]=lb.fit_transform(X[:,10])
#X[:,-1]=lb.fit_transform(X[:,-1])
#X
#it will be more feasible and easy to use pd.get_dummies when we have larger no of features

# %%
#from sklearn.compose import ColumnTransformer
#ct=ColumnTransformer(transformers=[('encoder',OneHotEncoder(),[5])],remainder='passthrough')
#ct=ColumnTransformer(transformers=[('encoder',OneHotEncoder(),[7])],remainder='passthrough')
#X=ct.fit_transform(X)
df
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     specialisation  mba_p workex  etest_p      status    Salary
# ...

# %%
final_data=pd.get_dummies(df,drop_first=True)
final_data
# Out:
#      ssc_p  hsc_p  degree_p  mba_p  etest_p    Salary  gender_M  ssc_b_Others  \
# 0    67.00  91.00     58.00  58.80     55.0  270000.0         1             1
# 1    79.33  78.33     77.48  66.28     86.5  200000.0         1             0
# 2    65.00  68.00     64.00  57.80     75.0  250000.0         1             0
# 3    56.00  52.00     52.00  59.43     66.0       0.0         1             0
# 4    85.80  73.60     73.30  55.50     96.8  425000.0         1             0
# ..     ...    ...       ...    ...      ...       ...       ...           ...
# 210  80.60  82.00     77.60  74.49     91.0  400000.0         1             1
# 211  58.00  60.00     72.00  53.62     74.0  275000.0         1             1
# 212  67.00  67.00     73.00  69.72     59.0  295000.0         1             1
# 213  74.00  66.00     58.00  60.23      0.0  204000.0         0             1
# 214  62.00  58.00     53.00  60.22     89.0       0.0         1             0
#
# ...

# %%
Y=final_data.iloc[:,5].values
X=final_data.drop('Salary',axis=1)

# %%
X
# Out:
#      ssc_p  hsc_p  degree_p  mba_p  etest_p  gender_M  ssc_b_Others  \
# 0    67.00  91.00     58.00  58.80     55.0         1             1
# 1    79.33  78.33     77.48  66.28     86.5         1             0
# 2    65.00  68.00     64.00  57.80     75.0         1             0
# 3    56.00  52.00     52.00  59.43     66.0         1             0
# 4    85.80  73.60     73.30  55.50     96.8         1             0
# ..     ...    ...       ...    ...      ...       ...           ...
# 210  80.60  82.00     77.60  74.49     91.0         1             1
# 211  58.00  60.00     72.00  53.62     74.0         1             1
# 212  67.00  67.00     73.00  69.72     59.0         1             1
# 213  74.00  66.00     58.00  60.23      0.0         0             1
# 214  62.00  58.00     53.00  60.22     89.0         1             0
#
#      hsc_b_Others  hsc_s_Commerce  hsc_s_Science  degree_t_Others  \
# 0               1               1              0                0
# ...

# %%
X.shape
# Out:
# (215, 15)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_new=sc.fit_transform(X)

# %%
X_new
# Out:
# array([[-0.02808697,  2.2688123 , -1.14010225, ...,  1.12390297,
#         -0.72444647,  0.67283185],
#        [ 1.11336869,  1.10344799,  1.51326671, ..., -0.88975652,
#          1.38036423,  0.67283185],
#        [-0.21323793,  0.15331275, -0.32284282, ..., -0.88975652,
#         -0.72444647,  0.67283185],
#        ...,
#        [-0.02808697,  0.06133451,  0.90304633, ..., -0.88975652,
#          1.38036423,  0.67283185],
#        [ 0.61994138, -0.03064373, -1.14010225, ...,  1.12390297,
#         -0.72444647,  0.67283185],
#        [-0.49096436, -0.76646966, -1.82115177, ...,  1.12390297,
#         -0.72444647, -1.48625544]])

# %%
Y
# Out:
# array([270000., 200000., 250000.,      0., 425000.,      0.,      0.,
#        252000., 231000.,      0., 260000., 250000.,      0., 218000.,
#             0., 200000., 300000.,      0.,      0., 236000., 265000.,
#        393000., 360000., 300000., 360000.,      0., 240000., 265000.,
#        350000.,      0., 250000.,      0., 278000., 260000.,      0.,
#        300000.,      0., 320000., 240000., 411000., 287000.,      0.,
#             0., 300000., 200000.,      0.,      0., 204000., 250000.,
#             0., 200000.,      0.,      0., 450000., 216000., 220000.,
#        240000., 360000., 268000., 265000., 260000., 300000., 240000.,
#             0., 240000.,      0., 275000., 275000.,      0., 275000.,
#        360000., 240000., 240000., 218000., 336000.,      0., 230000.,
#        500000., 270000.,      0., 240000., 300000.,      0., 300000.,
#        300000., 400000., 220000.,      0., 210000., 210000., 300000.,
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X_new,Y,test_size=0.3)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (150, 15)
# (65, 15)
# (150,)
# (65,)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Ypred=lr.predict(X_test)

# %%
Ypred
# Out:
# array([314330.47401558, 279626.96788647,  -9626.15718977,   6266.95937977,
#        323013.38612771,  17088.01800655, 271235.88200858,  16268.36389973,
#        257818.63319463,   2462.44791148, 248385.61430268,  18496.58745269,
#        288109.06371543,   9215.13020124, 309166.54150746, -17770.58683274,
#         -4857.41895049, 304827.98829438, 327496.80492077, 241783.49812203,
#        341128.57320843, 321559.02120167, 296725.31355216, 267997.64686363,
#        307638.28207829, 298536.25875749, -25014.00531723,   8139.74028505,
#          1533.81185259,  63365.89196793, 261954.12551321, 271125.24837663,
#        279097.57291394, -26648.12514186, 323187.92318063, 323924.54682558,
#        325717.23348347, 308067.08939383, 324066.54174984,  33777.00837255,
#        267887.81812095, 280635.03173611,   1491.37699205, -32171.82323485,
#        223834.31110535,    541.43397993, 243326.04478118, 268797.05082623,
# ...

# %%
Y_test
# Out:
# array([236000., 250000.,      0.,      0., 336000.,      0., 220000.,
#             0., 360000.,      0., 204000.,      0., 260000.,      0.,
#        300000.,      0.,      0., 450000., 280000., 220000., 300000.,
#        240000., 270000., 287000., 500000., 210000.,      0.,      0.,
#             0.,      0., 210000., 300000., 264000.,      0., 300000.,
#        275000., 690000., 300000., 400000.,      0., 240000., 380000.,
#             0.,      0., 240000.,      0., 250000., 240000., 265000.,
#        204000., 400000.,      0., 400000., 350000.,      0.,      0.,
#        300000., 200000., 270000.,      0.,      0., 300000., 360000.,
#             0., 218000.])

# %%
lr.score(X_train,Y_train)
# Out:
# 0.7514694441200197

# %%
lr.score(X_test,Y_test)
# Out:
# 0.8187418873483321

# %%
lr.coef_
# Out:
# array([ -6501.62676924,   -205.07413151,  -9258.17305688,  17284.93377923,
#          3882.98815114,   8944.01630663,    154.79680948,  -2406.32632972,
#         17697.02972455,  10040.26465629,   4678.06752574,  11614.50261068,
#         -9897.42638904,   3659.43375398, 134950.06559326])

# %%
lr.intercept_
# Out:
# 197385.3307923506
